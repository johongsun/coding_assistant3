# %% [markdown]
# <a href="https://colab.research.google.com/github/johongsun/coding_assistant3/blob/main/%EA%B9%80%EB%82%A8%ED%98%B8%EA%B5%90%EC%88%981%EA%B5%90%EC%8B%9C%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 12000 * 3 + 4500
# Out:
# 40500

# %%
from google.colab import files
올린것 = files.upload()
# Out:
#      <input type="file" id="files-728f95ef-f0a0-46e2-bc64-a4cef487e336" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-728f95ef-f0a0-46e2-bc64-a4cef487e336">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
files.download("파이썬 이메일.txt")

# %%
# @title 🍚 한 달 점심값 계산기 { run: "auto" }
점심값 = 10500   # @param {type:"slider", min:5000, max:15000, step:500}
주당_횟수 = 5   # @param {type:"integer"}
요일 = "월"     # @param ["월", "화", "수", "목", "금"]
커피 = True     # @param {type:"boolean"}

# %%
# !ls
# Out:
#  drive	 sample_data  '파이썬 이메일.txt'

# %%
# !pip install -q qrcode
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.3 MB/s eta 0:00:00

# %%
sum_of_evens = 0
for i in range(2, 101, 2):
    sum_of_evens += i
print(f"1부터 100까지 짝수의 합: {sum_of_evens}")
# Out:
# 1부터 100까지 짝수의 합: 2550
